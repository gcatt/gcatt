# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import time

# %%
import requests

# %%
r = requests.get("https://9gag.com")

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(r.__dict__)
# Out:
# {'_content': b'<!DOCTYPE html>\n<html lang="en">\n    <head>\n        \n<title>9GAG: Go Fun The World</title>\n\n<link rel="preconnect" href="https://assets-9gag-fun.9cache.com" />\n<link rel="preconnect" href="https://img-9gag-fun.9cache.com" />\n<link rel="preconnect" href="https://miscmedia-9gag-fun.9cache.com" />\n\n<link rel="image_src" href="https://images-cdn.9gag.com/img/9gag-og.png" />\n<link rel="canonical" href="https://9gag.com/" />\n<link rel="alternate" href="android-app://com.ninegag.android.app/http/9gag.com/" />\n<link rel="shortcut icon" href="https://assets-9gag-fun.9cache.com/s/fab0aa49/67c3578f29e49587225ade89e7f08077db6432e6/static/dist/core/img/favicon.ico" />\n\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta name="description" content="9GAG is your best source of FUN! Explore 9GAG for the most popular memes, breaking stories, awesome GIFs, and viral videos on the internet!" />\n<meta name="twitter:card" content="summary_large_imag
# ...

# %%
doc = BeautifulSoup(r.text, "html.parser")

# %%
doc.select_one(".container")

# %%
print(doc)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>9GAG: Go Fun The World</title>
# <link href="https://assets-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://img-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://miscmedia-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://images-cdn.9gag.com/img/9gag-og.png" rel="image_src"/>
# <link href="https://9gag.com/" rel="canonical"/>
# <link href="android-app://com.ninegag.android.app/http/9gag.com/" rel="alternate"/>
# <link href="https://assets-9gag-fun.9cache.com/s/fab0aa49/67c3578f29e49587225ade89e7f08077db6432e6/static/dist/core/img/favicon.ico" rel="shortcut icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="9GAG is your best source of FUN! Explore 9GAG for the most popular memes, breaking stories, awesome GIFs, and viral videos on the internet!" name="description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
doc.div
# Out:
# <div class="nav-wrap">
# <a class="logo" href="https://9gag.com" onclick="GAG.GA.trackPage('NavigationBar', 'TapLogo', '');">9GAG</a>
# <nav class="nav-menu">
# <ul class="secondary">
# <li>
# <a class="" href="http://bit.ly/3231YVs" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/3231YVs', Title:'🎲Random'});">🎲Random</a>
# </li>
# <li>
# <a class="" href="http://bit.ly/2WbA6LN" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2WbA6LN', Title:'📱Get App'});" target="_blank">📱Get App</a>
# </li>
# <li>
# <a class="" href="http://bit.ly/2GEH9WG" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2GEH9WG', Title:'🛒Shop'});" target="_blank">🛒Shop</a>
# </li>
# <li>
# <a class="" href="http://bit.ly/2IOdoE6" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2IOdoE6', Title:'🦠COVID-19'});">🦠COVID-19</a>
# </li>
# <li>
# ...

# %%
doc.div.a
# Out:
# <a class="logo" href="https://9gag.com" onclick="GAG.GA.trackPage('NavigationBar', 'TapLogo', '');">9GAG</a>

# %%
doc.find_all("div", class_="headbar-search-suggest ui-widget")
# Out:
# [<div class="headbar-search-suggest ui-widget" id="jsid-headbar-search-suggest">
#  </div>]

# %%
doc.h1
# Out:
# <h1>Drop to upload</h1>

# %%
doc.find_all("div", class_="popup-menu search hide")
# Out:
# [<div class="popup-menu search hide" id="jsid-header-search-dropdown">
#  <form action="https://9gag.com/search" class="badge-header-search" id="headbar-search" onsubmit="GAG.GA.track('Search','SubmitSearch', 'Search', '', {Element: 'NavigationBarInputBox'})">
#  <div class="headbar-search">
#  <input class="ui-autocomplete-input search_input" data-placeholder="Type to search…" id="jsid-search-input" name="query" tabindex="1" type="text"/>
#  </div>
#  <div class="headbar-search-suggest ui-widget" id="jsid-headbar-search-suggest">
#  </div>
#  </form>
#  </div>]

# %%
doc.find_all("div", class_="headbar-search-suggest")
# Out:
# [<div class="headbar-search-suggest ui-widget" id="jsid-headbar-search-suggest">
#  </div>]

# %%
doc.find_all("a", class_="btn-primary")
# Out:
# [<a class="btn-primary" href="https://9gag.com/signup" id="jsid-signup-button" onclick="GAG.GA.trackPage('NavigationBar', 'TapSignUp');" rel="nofollow">Sign up</a>,
#  <a class="btn-primary" href="javascript:void(0);" id="jsid-upload-btn" onclick="GAG.GA.trackPage('UploadAction', 'TapUpload', '', {Element: 'NavigationBarButton'});" rel="nofollow">Upload</a>]

# %%
doc.div.select("a")
# Out:
# [<a class="logo" href="https://9gag.com" onclick="GAG.GA.trackPage('NavigationBar', 'TapLogo', '');">9GAG</a>,
#  <a class="" href="http://bit.ly/3231YVs" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/3231YVs', Title:'🎲Random'});">🎲Random</a>,
#  <a class="" href="http://bit.ly/2WbA6LN" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2WbA6LN', Title:'📱Get App'});" target="_blank">📱Get App</a>,
#  <a class="" href="http://bit.ly/2GEH9WG" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2GEH9WG', Title:'🛒Shop'});" target="_blank">🛒Shop</a>,
#  <a class="" href="http://bit.ly/2IOdoE6" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2IOdoE6', Title:'🦠COVID-19'});">🦠COVID-19</a>,
#  <a class="new" href="https://bit.ly/2vGmG27" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'https://bit.ly/2vGmG27', Title:'Chat'});">Chat</a>,
# ...

# %%
doc.findAll("p", class_="message")
# Out:
# []

# %%
doc.p
# Out:
# <p>Hey <span id="jsid-banner-confirm-email-username"></span>, please verify your email address. If you didn't receive an email, we can <a href="/member/resend-confirmation">resend it</a> or you can <a href="https://9gag.com/settings">change your email address</a>.</p>

# %%
doc.p.text
# Out:
# "Hey , please verify your email address. If you didn't receive an email, we can resend it or you can change your email address."

# %%
doc.findAll("div", id_="container")
# Out:
# []

# %%
d = requests.get("https://9gag.com/gag/ao5QLpe")

# %%
print(d.__dict__)
# Out:
# {'_content': b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n<title>Attention Required! | Cloudflare</title>\n<meta name="captcha-bypass" id="captcha-bypass" />\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" type="text/css" media="screen,projection" />\n<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' href="/cdn-cgi/styles/cf.errors.ie.css" type="text/css" media="
# ...

# %%
doc.select(".cf-column")
# Out:
# []

# %%
print(doc)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>9GAG: Go Fun The World</title>
# <link href="https://assets-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://img-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://miscmedia-9gag-fun.9cache.com" rel="preconnect"/>
# <link href="https://images-cdn.9gag.com/img/9gag-og.png" rel="image_src"/>
# <link href="https://9gag.com/" rel="canonical"/>
# <link href="android-app://com.ninegag.android.app/http/9gag.com/" rel="alternate"/>
# <link href="https://assets-9gag-fun.9cache.com/s/fab0aa49/67c3578f29e49587225ade89e7f08077db6432e6/static/dist/core/img/favicon.ico" rel="shortcut icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="9GAG is your best source of FUN! Explore 9GAG for the most popular memes, breaking stories, awesome GIFs, and viral videos on the internet!" name="description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
doc.findAll("p")
# Out:
# [<p>Hey <span id="jsid-banner-confirm-email-username"></span>, please verify your email address. If you didn't receive an email, we can <a href="/member/resend-confirmation">resend it</a> or you can <a href="https://9gag.com/settings">change your email address</a>.</p>,
#  <p class="close">
#  <span class="badge-toast-message"></span>
#  <a class="btn-close badge-toast-close" href="#">✖</a>
#  </p>,
#  <p>Choose how you want to upload the post</p>,
#  <p>Drop image to upload or</p>,
#  <p>Paste image URL</p>,
#  <p>Paste Video URL</p>,
#  <p class="tooltip">Available on iOS &amp; Android only.</p>,
#  <p>Make meme</p>,
#  <p>Type or paste Image URL</p>,
#  <p></p>,
#  <p>An accurate, descriptive title can help people discover your post.</p>,
#  <p></p>,
#  <p class="count" id="jsid-char-count">280</p>,
#  <p>This is sensitive</p>,
#  <p>Attribute original poster</p>,
#  <p>Submitting to the right section to make sure your post gets the right exposure it deserves!
# ...

# %%
doc.select("p")[3].text
# Out:
# 'Drop image to upload or'

# %%
doc.select("div")[4].text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nUpload\n\n\n\n\n\n\n\n\n\nMy Profile\nSettings\nLogout\n\n\n'

# %%
doc.findAll("h1")
# Out:
# [<h1>Drop to upload</h1>]

# %%
print(doc.a)
# Out:
# <a class="logo" href="https://9gag.com" onclick="GAG.GA.trackPage('NavigationBar', 'TapLogo', '');">9GAG</a>

# %%
doc.img
# Out:
# <img alt="Avatar" id="jsid-avatar" src=""/>

# %%
doc.findAll("img")
# Out:
# [<img alt="Avatar" id="jsid-avatar" src=""/>, <img data-dz-thumbnail=""/>]

# %%
doc.findAll("div")
# Out:
# [<div class="nav-wrap">
#  <a class="logo" href="https://9gag.com" onclick="GAG.GA.trackPage('NavigationBar', 'TapLogo', '');">9GAG</a>
#  <nav class="nav-menu">
#  <ul class="secondary">
#  <li>
#  <a class="" href="http://bit.ly/3231YVs" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/3231YVs', Title:'🎲Random'});">🎲Random</a>
#  </li>
#  <li>
#  <a class="" href="http://bit.ly/2WbA6LN" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2WbA6LN', Title:'📱Get App'});" target="_blank">📱Get App</a>
#  </li>
#  <li>
#  <a class="" href="http://bit.ly/2GEH9WG" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2GEH9WG', Title:'🛒Shop'});" target="_blank">🛒Shop</a>
#  </li>
#  <li>
#  <a class="" href="http://bit.ly/2IOdoE6" onclick="GAG.GA.trackPage('NavigationBar','TapLink', '', { Url:'http://bit.ly/2IOdoE6', Title:'🦠COVID-19'});">🦠COVID-19</a>
#  </li>
#  <li>
# ...

# %%
doc.findAll("a", class_="btn-close badge-toast-close")
# Out:
# [<a class="btn-close badge-toast-close" href="#">✖</a>]

# %%
url = "https://9gag.com/coronavirus"

r = requests.get(url)
time.sleep(1)
doc = BeautifulSoup(r.text, 'html.parser')

# %%
doc.select_one("a").attrs["href"]
# Out:
# 'https://www.cloudflare.com/5xx-error-landing?utm_source=error_footer'

# %%
doc.select("p")[3].text
# Out:
# '\nCloudflare Ray ID: 57b008e49b82ce93\n•\nYour IP: 194.230.147.255\n•\nPerformance & security by Cloudflare\n'
